# %%
import pandas as pd

# %% [markdown]
# ### Reading Files

# %%
#dfe = dfe[0:0]
dfe = pd.read_excel(r"C:\Users\reshm\Documents\My Jupyter Repo\countyregion.xlsx", sheet_name = 'Sheet2')
dfe
# Out:
#              Country           Region
# 0      Åland Islands  Northern Europe
# 1            Albania  Southern Europe
# 2            Algeria  Northern Africa
# 3     American Samoa        Polynesia
# 4            Andorra  Southern Europe
# ..               ...              ...
# 279    North America         Americas
# 280    North America         Americas
# 281    North America         Americas
# 282    North America         Americas
# 283    North America         Americas
#
# [284 rows x 2 columns]

# %%
#dfc = dfc[0:0]
dfc = pd.read_csv(r"C:\Users\reshm\Documents\My Jupyter Repo\countyregion.csv", sep = '\t')
dfc
# Out:
#              Country           Region
# 0            Algeria  Northern Africa
# 1              Egypt  Northern Africa
# 2              Libya  Northern Africa
# 3            Morocco  Northern Africa
# 4              Sudan  Northern Africa
# ..               ...              ...
# 190            Samoa  Pacific Islands
# 191  Solomon Islands  Pacific Islands
# 192            Tonga  Pacific Islands
# 193           Tuvalu  Pacific Islands
# 194          Vanuatu  Pacific Islands
#
# [195 rows x 2 columns]

# %%
pd.set_option('display.max.rows', 10)

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  195 non-null    object
#  1   Region   195 non-null    object
# dtypes: object(2)
# memory usage: 3.2+ KB

# %%
print(dfc.head(5))
print(dfc.tail(5))
# Out:
#    Country           Region
# 0  Algeria  Northern Africa
# 1    Egypt  Northern Africa
# 2    Libya  Northern Africa
# 3  Morocco  Northern Africa
# 4    Sudan  Northern Africa
#              Country           Region
# 190            Samoa  Pacific Islands
# 191  Solomon Islands  Pacific Islands
# 192            Tonga  Pacific Islands
# 193           Tuvalu  Pacific Islands
# 194          Vanuatu  Pacific Islands

# %%
dfc['Region']
# Out:
# 0      Northern Africa
# 1      Northern Africa
# 2      Northern Africa
# 3      Northern Africa
# 4      Northern Africa
#             ...
# 190    Pacific Islands
# 191    Pacific Islands
# 192    Pacific Islands
# 193    Pacific Islands
# 194    Pacific Islands
# Name: Region, Length: 195, dtype: object

# %%
dfc.loc[190]
# Out:
# Country              Samoa
# Region     Pacific Islands
# Name: 190, dtype: object

# %%
dfc.iloc[190]
# Out:
# Country              Samoa
# Region     Pacific Islands
# Name: 190, dtype: object

# %%
dfc[dfc['Region'] == 'South Asia']
# Out:
#          Country      Region
# 112  Afghanistan  South Asia
# 113   Bangladesh  South Asia
# 114       Bhutan  South Asia
# 115        India  South Asia
# 116     Maldives  South Asia
# 117        Nepal  South Asia
# 118     Pakistan  South Asia
# 119    Sri Lanka  South Asia

# %%
df_world = pd.read_csv(r"C:\Users\reshm\Documents\My Jupyter Repo\world_population.csv")
df_world
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# ### Filtering, Sorting

# %%
df_world[df_world['Rank'] <= 10]
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 16      8  BGD        Bangladesh             Dhaka           Asia
# 27      7  BRA            Brazil          Brasilia  South America
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 93      4  IDN         Indonesia           Jakarta           Asia
# 131    10  MEX            Mexico       Mexico City  North America
# 149     6  NGA           Nigeria             Abuja         Africa
# 156     5  PAK          Pakistan         Islamabad           Asia
# 171     9  RUS            Russia            Moscow         Europe
# 221     3  USA     United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16         171186372        167420951        157830000        148391139
# 27         215313498        213196304        205188205        196353492
# ...

# %%
specific_countries = ['Bangladesh', 'Brazil']

df_world[df_world['Country/Territory'].isin(specific_countries)] #IN (List)
# Out:
#     Rank CCA3 Country/Territory   Capital      Continent  2022 Population  \
# 16     8  BGD        Bangladesh     Dhaka           Asia        171186372
# 27     7  BRA            Brazil  Brasilia  South America        215313498
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 16        167420951        157830000        148391139        129193327
# 27        213196304        205188205        196353492        175873720
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 16        107147651         83929765         67541860      147570
# 27        150706446        122288383         96369875     8515767
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 16          1160.0350       1.0108                         2.15
# 27            25.2841       1.0046                         2.70

# %%
df_world[df_world['Country/Territory'].str.contains('United')] #ILIKE, LIKE string
# Out:
#      Rank CCA3             Country/Territory           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219          9441129          9287289          8916899          8481771
# 220         67508936         67059474         65224364         62760039
# 221        338289857        335942003        324607776        311182845
# 222            99465           100442           102803           106142
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219          3275333          1900151          1014048           298084
# ...

# %%
df2 = df_world.set_index('Country/Territory')
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country/Territory
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH          El Aaiún    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
df2.filter(items = ['Continent', 'CCA3'], axis = 1)
# Out:
#                   Continent CCA3
# Country/Territory
# Afghanistan            Asia  AFG
# Albania              Europe  ALB
# Algeria              Africa  DZA
# American Samoa      Oceania  ASM
# Andorra              Europe  AND
# ...                     ...  ...
# Wallis and Futuna   Oceania  WLF
# Western Sahara       Africa  ESH
# Yemen                  Asia  YEM
# Zambia               Africa  ZMB
# Zimbabwe             Africa  ZWE
#
# [234 rows x 2 columns]

# %%
df2.filter(items = ['Zimbabwe'], axis = 0)
# Out:
#           Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Zimbabwe    74  ZWE  Harare    Africa         16320537         15669666
#
#           2015 Population  2010 Population  2000 Population  1990 Population  \
# Zimbabwe         14154937         12839771         11834676         10113893
#
#           1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Zimbabwe          7049926          5202918      390757            41.7665
#
#           Growth Rate  World Population Percentage
# Zimbabwe       1.0204                          0.2

# %%
df_world[df_world['Rank'] < 10].sort_values(by = ['Country/Territory','Continent'], ascending = [False,True])
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 221     3  USA     United States  Washington, D.C.  North America
# 171     9  RUS            Russia            Moscow         Europe
# 156     5  PAK          Pakistan         Islamabad           Asia
# 149     6  NGA           Nigeria             Abuja         Africa
# 93      4  IDN         Indonesia           Jakarta           Asia
# 92      2  IND             India         New Delhi           Asia
# 41      1  CHN             China           Beijing           Asia
# 27      7  BRA            Brazil          Brasilia  South America
# 16      8  BGD        Bangladesh             Dhaka           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 221        338289857        335942003        324607776        311182845
# 171        144713314        145617329        144668389        143242599
# 156        235824862        227196741        210969298        194454498
# ...

# %% [markdown]
# ### Indexing

# %%
dfi = pd.read_csv(r"C:\Users\reshm\Documents\My Jupyter Repo\world_population.csv", index_col = "Country/Territory")

dfi
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country/Territory
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH          El Aaiún    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
dfi.reset_index(inplace=True)
dfi
# Out:
#      Country/Territory  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
dfi.set_index('Country/Territory', inplace = True)
dfi
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country/Territory
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH          El Aaiún    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
dfi.loc['Albania']
# Out:
# Rank                               138
# CCA3                               ALB
# Capital                         Tirana
# Continent                       Europe
# 2022 Population                2842321
#                                 ...
# 1970 Population                2324731
# Area (km²)                       28748
# Density (per km²)              98.8702
# Growth Rate                     0.9957
# World Population Percentage       0.04
# Name: Albania, Length: 16, dtype: object

# %%
dfi.iloc[1]
# Out:
# Rank                               138
# CCA3                               ALB
# Capital                         Tirana
# Continent                       Europe
# 2022 Population                2842321
#                                 ...
# 1970 Population                2324731
# Area (km²)                       28748
# Density (per km²)              98.8702
# Growth Rate                     0.9957
# World Population Percentage       0.04
# Name: Albania, Length: 16, dtype: object

# %%
dfi.reset_index(inplace = True)

# %%
dfi.set_index(['Continent','Country/Territory'], inplace = True)

# %%
dfi.sort_index(ascending=[False,True])
# Out:
#                                  Rank CCA3       Capital  2022 Population  \
# Continent     Country/Territory
# South America Argentina            33  ARG  Buenos Aires         45510318
#               Bolivia              80  BOL         Sucre         12224110
#               Brazil                7  BRA      Brasilia        215313498
#               Chile                65  CHL      Santiago         19603733
#               Colombia             28  COL        Bogota         51874024
# ...                               ...  ...           ...              ...
# Africa        Tunisia              79  TUN         Tunis         12356117
#               Uganda               31  UGA       Kampala         47249585
#               Western Sahara      172  ESH      El Aaiún           575986
#               Zambia               63  ZMB        Lusaka         20017675
#               Zimbabwe             74  ZWE        Harare         16320537
#
# ...

# %%
dfi.loc['Africa','Angola']
# Out:
# Rank                                 42
# CCA3                                AGO
# Capital                          Luanda
# 2022 Population                35588987
# 2020 Population                33428485
#                                  ...
# 1970 Population                 6029700
# Area (km²)                      1246700
# Density (per km²)               28.5466
# Growth Rate                      1.0315
# World Population Percentage        0.45
# Name: (Africa, Angola), Length: 15, dtype: object
